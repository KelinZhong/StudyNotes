# %% [markdown]
# # Causal Machine Learning
#
# - Foundations
# - Experimental
# - Observational
# - Identification
# - Individual effects
# - Uplift modeling
# - Causal forests
# - End-to-end pipeline and systematic insight
