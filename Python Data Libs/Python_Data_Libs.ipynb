# %% [markdown]
# ---
#
# ## File Index
#
# ### Reference Notes
# | File | Coverage | Use when |
# | :--- | :--- | :--- |
# | `Reference_NumPy.ipynb` | Array creation, indexing, broadcasting, linear algebra, random, performance | Looking up NumPy syntax or API |
# | `Reference_Pandas.ipynb` | Inspection, selection, nulls, groupby, joins, windows, datetime, strings, I/O | Looking up Pandas syntax or API |
# | `Reference_Matplotlib.ipynb` | Figure/axes, plot types, subplots, styling, annotations, export | Looking up Matplotlib syntax |
#
# ### Data Manipulation
# | File | Coverage | Use when |
# | :--- | :--- | :--- |
# | `DM_Basic.ipynb` | Audit checklist, dtype fixes, missing values, duplicates, outliers, column names | First pass on a raw dataset |
# | `DM_Intermediate.ipynb` | Wide/long reshaping, advanced GroupBy, multi-table pipelines, time-series, nested data, multi-file loading | Getting data into the right shape for analysis |
# | `DM_Advanced.ipynb` | Categorical encoding, scaling, binning, date features, lag/window features, text features, leakage detection | Feature engineering for ML/modeling |
#
# ---
#
# ## How to Use These Notes
#
# - **Reference notes** (`Reference_*.ipynb`) are **syntax-first** — look up how to call a function, what arguments it takes, and what the common mistakes are. Use the *When to Use* table at the top of each file to navigate quickly.
#
# - **Data manipulation notes** (`DM_*.ipynb`) are **pattern-first** — each section answers "you have data that looks like X, here is the full pipeline to solve it." They assume you already know the Pandas/NumPy API.
#
# - Every section ends with a **Common mistakes** block and every file ends with a **Decision Guide** — use these during interviews to sanity-check your approach.
#
# ---
#
# ## Folder Structure
#
# ```
# python_data_libs/
# ├── Python_Data_Libs.ipynb       ← this file (cover + index)
# │
# ├── Reference_NumPy.ipynb        ← NumPy syntax reference
# ├── Reference_Pandas.ipynb       ← Pandas syntax reference
# │
# ├── DM_Basic.ipynb               ← Data cleaning & quality control
# ├── DM_Intermediate.ipynb        ← Reshaping & combining data
# └── DM_Advanced.ipynb            ← Feature engineering
# ```
