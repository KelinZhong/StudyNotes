# %% [markdown]
# # Deep Learning
#
# ### How Neural Networks Learn
#
# ### Training Networks Effectively
#
# ### Prevent Overfitting
#
# ### CNN Understanding Images
#
# ### Handling Sequences
#
# ### How Attention Works
#
# ### Using Pretrained Models
