# %% [markdown]
# # R Data Libraries
#
# - Base R (vectors, matrices, linear algebra)
# - Tidyverse (dplyr, tidyr, stringr, lubridate)
# - Data Manipulation (basic, intermediate, advanced)
# - Business Metrics in R (ggplot2)
# - Sampling with base R and dplyr
# - Statistical Inference in R
#
# This is the R companion to the Python Data Libs chapter -- same structure,
# same teaching goals, ported to the tidyverse / tidymodels / base R stack.
# See the intro page for a guided table of contents.
