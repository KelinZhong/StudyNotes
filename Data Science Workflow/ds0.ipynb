# %% [markdown]
# # Data Science Workflow
#
# - Problem Framing
# - Explora Data Analysis (EDA)
# - Analysis
# - Features
# - Modeling
# - Validation
# - Deployment
# - Communication
# - Analytics Case Study
# - Machine Learning Case Study
