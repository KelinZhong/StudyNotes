# %% [markdown]
# # Python Data Structures and Algorithm
#
# ### Study Guides
#
# Teaches you the concept from scratch with explanations, comparisons, and worked examples, designed to be read linearly when learning a topic for the first time.
#
# ### Cheat Sheet
#
# Assumes you already understand the topic and gives you the template, key decision rules, and common mistakes for quick review before an interview.
#
# ### References
#
# A flat lookup tool with no prose or explanations, designed to be scanned or ctrl+F'd when you need to recall a specific trick, function, or code snippet mid-problem.
