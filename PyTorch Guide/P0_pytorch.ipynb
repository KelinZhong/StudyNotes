# %% [markdown]
# # PyTorch Guide
#
# ### Tensors
#
# ### Autograd
#
# ### Defining models
#
# ### Training loop
#
# ### CNN
#
# ### RNN/LSTM
#
# ### Debugging & monitoring
#
# ### Pretrained models
#
# ### Fine-tuning
